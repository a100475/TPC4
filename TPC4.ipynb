# %%
from re import M
from tkinter import N


def listar( cinema ): #funciona
    i = 1
    for n in cinema:
        nlugares, Vendidos, filme = n
        print("Na sala", i, "está em exibição o filme:", filme)
        i = i + 1
        

    return


def disponivel( cinema, filme, lugar ):
    for n in cinema:
        nlugares, Vendidos, filmep = n
        if filme == filmep:
            if lugar > nlugares:
                print("O lugar", lugar, "não existe")
                available = False
            else:
                if lugar in Vendidos:
                    print("O lugar", lugar, "para o filme", filmep, "no cinema está indisponivel")
                    available = False
                else:
                    print("O lugar", lugar, "para o filme", filmep, "no cinema está disponivel")
                    available = True
            
            
            


    return available


def vendebilhete( cinema, filme, lugar ):
    disp = disponivel(cinema, filme, lugar)
    if disp == True:
        for n in cinema:
            nlugares, Vendidos, filmep = n
            if filme == filmep:
                if lugar > nlugares:
                    print("O lugar", lugar, "não existe")
                else:
                    Vendidos.append(lugar)
                    print("Este lugar está agora ocupado")



    return


def listardisponiblidades( cinema ):
    salas = 1
    for n in cinema:
        nlugares, Vendidos, filmep = n
        print("Na sala", salas, "está a ser exibido o filme", filmep,"para o qual estão disponiveis", (nlugares - len(Vendidos)), "lugares")
        salas = salas + 1

    return


def inserirSala( cinema, sala ): #funciona
    existe = False
    for n in cinema:
        if sala == n:
            print("Essa sala já existe")
            existe = True
    if existe == False:
        print("Insira o número de lugares")
        nlugaresnew = int(input())
        print("Que filme está a ser exibido nessa sala")
        filmenew = str(input())
        oc = []
        newsala = [nlugaresnew, oc, filmenew]
        cinema.append(newsala)
            
    return 

def execução( funcao ):
    if funcao == 1:
        listar( cinemaToday )


    if funcao == 2:
        print("Insira o número da sala")
        filme = int(input())
        print("Insira o número do lugar")
        lugar = int(input())
        disponivel( cinemaToday, cinemaToday[filme - 1][2], lugar )


    if funcao == 3:
        print("Insira o número da sala")
        filme = int(input())
        print("Insira o número do lugar")
        lugar = int(input())
        vendebilhete( cinemaToday, cinemaToday[filme - 1][2], lugar )


    if funcao == 4:
        listardisponiblidades( cinemaToday )


    if funcao == 5:
        print("Insira o número da nova sala")
        sala = int(input())
        inserirSala( cinemaToday, sala )




    return




def menu( start ):
    while start == True:
        print("(1) Listar filmes por sala")
        print("(2) Verificar disponibilidade de um lugar")
        print("(3) Vender bilhete")
        print("(4) Listar disponibilidade de lugares")
        print("(5) Inserir nova sala de cinema")
        print("(0) Encerrar")
        funcao = int(input())
        if funcao < 0 or funcao > 5:
            print("Função inválida")
        elif funcao == 0:
            print("Fim do programa")
            start = False
        else:
            execução(funcao)
    

    return

    





# sala = [nlugares, Vendidos, filme]
oc1 = [2, 3, 5, 7, 11]
oc2 = [1, 2, 3, 4]
oc3 = [17, 18, 19]
oc4 = [7, 2, 18]
sala1 = [20, oc1, "Twilight"]
sala2 = [20, oc2, "Lego Movie"]
sala3 = [20, oc3, "Hannibal"]
sala4 = [20, oc4, "Star Wars"]

cinemaToday = [sala1, sala2, sala3, sala4]

Menu = True
menu( Menu )
